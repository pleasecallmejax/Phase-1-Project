# %% [markdown]
# # **Collecting Data and Reviews from Yelp API**

# %% [markdown]
# ## Import Packages

# %% [markdown]
# # Business Data

# %% [markdown]
# ## Request

# %% [markdown]
# ## Parse

# %% [markdown]
# ## Collect All Data

# %% [markdown]
# ## Creating Function to Clean Data

# %% [markdown]
# #  Business Reviews

# %% [markdown]
# ## Request

# %% [markdown]
# ## Parse

# %% [markdown]
# ## Collect All Reviews
