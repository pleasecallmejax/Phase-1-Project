# %% [markdown]
# # Generating Businesses Data .CSV

# %% [markdown]
# * Pull request
# * Parse and filter?
# * Review prior functions?

# %% [markdown]
# ## Imports

# %%
import requests
import pandas as pd
import json
import csv
import numpy as np

with open(r'C:\Users\bmcca\.secret\yelp_api.json') as f:
    keys = json.load(f)

client_id = keys['id']
yelp_key = keys['key']

# %% [markdown]
# ## Creating the Pull Request

# %%
def yelp_request_offset(term, location, yelp_key, offset=0, verbose=False):
    '''Adapted from Yelp API Lab: https://github.com/BenJMcCarty/dsc-yelp-api-lab/tree/solution'''
    
    url = 'https://api.yelp.com/v3/businesses/search'

    headers = {
            'Authorization': 'Bearer {}'.format(yelp_key),
        }

    url_params = {
                    'term': term.replace(' ', '+'),
                    'location': location.replace(' ', '+'),
                    'limit': 50,
                    'offset': offset
                        }
    
    response = requests.get(url, headers=headers, params=url_params)
    
    if verbose == True:
        print(response)
        print(type(response.text))
        print(response.text[:1000])
        
    return response.json()

# %%
def parse_data(list_of_data):
    '''Adapted from Tyrell's code'''  

    # Create empty list to store results
    
    parsed_data = []
    
    # Loop through each business in the list of businesses
    # Add specific k:v pairs to a dictionary
    
    for business in list_of_data:
        if 'price' not in business:
            business['price'] = np.nan
            
            # Verify that the "price" key is in the selected business dict
            
        details = {'name': business['name'],
                     'location': ' '.join(business['location']['display_address']),
                     'id': business['id'],
                     'alias': business['categories'][0]['alias'],
                     'title': business['categories'][0]['title'],
                     'rating': business['rating'],
                     'review_count': business['review_count'],
                     'price': business['price'],
                     'latitude': business['coordinates']['latitude'],
                     'longitude': business['coordinates']['longitude']
                    }
        # Add the new dictionary to the previous list
        
        parsed_data.append(details)
    
    # Create a DataFrame from the resulting list
    
    df_parsed_data = pd.DataFrame(parsed_data)

    
    return df_parsed_data

# %%
def get_full_data(term, location, yelp_key, file_name = 'data/wineries_raw.csv'):
    '''Requests all results from Yelp API; saves as a .csv; and returns a DataFrame.'''

    # Create a .csv to store results
    blank_df = pd.DataFrame()
    blank_df.to_csv(file_name)
    
    # Process first request to Yelp API and calculate number of pages 
    results = yelp_request_offset(term, location, yelp_key, offset=0, 
                                  verbose=False)
    num_pages = results['total']//50+1
    
    # Print out confirmation feedback
    print(f'For {term} and {location}: ')
    print(f"    Total number of results: {results['total']}.")
    print(f'    Total number of pages: {num_pages}.')
    
    # Create offset for further results and create empty list
    offset = 0

    # Retrieves remaining pages
    for num in range(num_pages-1):
        try:
            # Process API request
            results = yelp_request_offset(term, location, yelp_key,
                                          offset=offset, verbose=False)
            
            # From results, take values from "Businesses" key and save
            parsed_results = parse_data(results['businesses'])
          
            # Save resulting DF to .csv from top
            parsed_results.to_csv(file_name, mode='a', index = False)
            
            # Increase offset to move to next "page" of data
            offset += 50
            
        except:
            # If error, print where the error happens
            print(f'Error on page {num}.')
            # Then save the results so far to the .csv
            parsed_results.to_csv(file_name, mode='a', index = False)


    return parsed_results

# %% [markdown]
# ## Cleaning Data

# %%
def sort_by_aliases(raw_data = 'data/wineries_raw.csv'):

    # Read in businesses
    df2 = pd.read_csv(raw_data, header = 1)

    # Create new DF filtering alias and title columns
    df2_alias = df2.loc[:,['alias', 'title']]

    # Identify top 2 aliases 
    df2_alias_count = df2_alias.groupby('alias').count().sort_values(['title'],\
                                                            ascending=False)[:2]

    # Note: initially tried top 3, but it returned distributors, not wineries

    df2_alias_count.reset_index(inplace=True)
    
    print("Top two aliases: ")
    print(df2_alias_count)

    # display them as a list
    aliases_top_2 = df2_alias_count['alias'].tolist()

    # Selecting rows based on condition and saving

    df3 = df2[df2['alias'].isin(aliases_top_2)]

    df3.to_csv('data/wineries_filtered_alias.csv', index = False)

    
    return "Saved to 'data/wineries_filtered_alias.csv'"

# %% [markdown]
# ## Testing Functions

# %% [markdown]
# ### Get Data

# %%
get_full_data('winery','San Diego', yelp_key)
# Out:
# For winery and San Diego:
#     Total number of results: 262.
#     Total number of pages: 6.
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_test = pd.read_csv('data/wineries_raw.csv', header = 1)
df_test
# Out:
#                                  name  \
# 0    The Winery Restaurant & Wine Bar
# 1                     Bernardo Winery
# 2                   Baja Winery Tours
# 3          Callaway Vineyard & Winery
# 4                    Négociant Winery
# ..                                ...
# 195               San Diego Limobuses
# 196            Alpine Discount Liquor
# 197            Village Wine & Spirits
# 198     The Destination Wedding Group
# 199                            BevMo!
#
#                                               location  \
# 0    4301 La Jolla Village Dr Ste 2040 San Diego, C...
# 1     13330 Paseo Del Verano Norte San Diego, CA 92128
# 2                     4629 Cass St San Diego, CA 92109
# 3              517 4th Ave Ste 101 San Diego, CA 92101
# 4               2419 El Cajon Blvd San Diego, CA 92104
# ..                                                 ...
# 195         3333 Midway Dr Ste 206 San Diego, CA 92110
# 196                  2223 Alpine Blvd Alpine, CA 91901
# 197            1552 Encinitas Blvd Encinitas, CA 92024
# 198                                Escondido, CA 92033
# 199       168 S Solana Hills Dr Solana Beach, CA 92075
#
#                          id             alias                 title rating  \
# 0    76ADW8x8J_69qbtsc5F-2g              bars                  Bars    4.0
# 1    DknnpiG1p4OoM1maFshzXA   winetastingroom     Wine Tasting Room    4.5
# 2    vVaNDvLrCCE_Cw_DyPnBpA         winetours            Wine Tours    5.0
# 3    Cn2_bpTngghYW1ej4zreZg   winetastingroom     Wine Tasting Room    5.0
# 4    Cc1sQWRWgGyMCjzX2mmMQQ   winetastingroom     Wine Tasting Room    4.5
# ..                      ...               ...                   ...    ...
# 195  SCaFGyzrTGTI6aQHhLxbgA             limos                 Limos    3.0
# 196  -ARx5ShNxJgjyahKnikTnA     beer_and_wine  Beer, Wine & Spirits    3.5
# 197  XkGnb-YxP5MK_ok1X011RA     beer_and_wine  Beer, Wine & Spirits    4.0
# 198  lJwxe_fjdt-e8xPrDq63fA  wedding_planning      Wedding Planning    5.0
# 199  m2LBkxbaDBg2VDFAW4Q9Gg     beer_and_wine  Beer, Wine & Spirits    3.0
#
#     review_count price          latitude          longitude
# 0            492    $$        32.8724284       -117.2137748
# 1            626    $$           33.0328         -117.04646
# 2             66   NaN        32.7989164       -117.2521107
# 3            100    $$  32.7107506117294  -117.160917759246
# 4            103    $$          32.75488         -117.13828
# ..           ...   ...               ...                ...
# 195           46   NaN          32.75006         -117.21138
# 196            3     $        32.8352874       -116.7659099
# 197           24    $$        33.0458964       -117.2555835
# 198           18   NaN          33.12347         -117.08652
# 199           31    $$  32.9946263099766  -117.257885867471
#
# [200 rows x 10 columns]

# %% [markdown]
# ### Clean Data

# %%
df_test_clean = sort_by_aliases(raw_data = 'data/wineries_raw.csv')
df_test_clean
# Out:
# Top two aliases:
#              alias  title
# 0         wineries     49
# 1  winetastingroom     33
# "Saved to 'data/wineries_filtered_alias.csv'"

# %%
df_test2 = pd.read_csv('data/wineries_filtered_alias.csv')
df_test2
# Out:
#                                              name  \
# 0                                 Bernardo Winery
# 1                      Callaway Vineyard & Winery
# 2                                Négociant Winery
# 3            San Pasqual Winery - Seaport Village
# 4              Domaine Artefact Vineyard & Winery
# ..                                            ...
# 77  Roll OutThe Barrell Charity Event by Meritage
# 78                               Licores Kentucky
# 79                                      Barrica 9
# 80                          RL Liquid Assets, Inc
# 81      Cactus Star Vineyard at Scaredy Cat Ranch
#
#                                              location                      id  \
# 0    13330 Paseo Del Verano Norte San Diego, CA 92128  DknnpiG1p4OoM1maFshzXA
# 1             517 4th Ave Ste 101 San Diego, CA 92101  Cn2_bpTngghYW1ej4zreZg
# 2              2419 El Cajon Blvd San Diego, CA 92104  Cc1sQWRWgGyMCjzX2mmMQQ
# 3                 805 W Harbor Dr San Diego, CA 92101  gMW1RvyLu90RSQAY9UrIHw
# 4        15404 Highland Valley Rd Escondido, CA 92025  WqVbxY77Ag96X90LultCUw
# ..                                                ...                     ...
# 77       162 S Rancho Santa Fe Rd Encinitas, CA 92024  wyLm9fIoamN-VALcu3nUVg
# 78  Calle Puerto y 3ra S/N Col. Centro 22000 Tijua...  B7gID-M2EsdpthrTcwTNYA
# 79  Av. Revolución 1265 Col. Zona Centro 22000 Tij...  HxTqmzT4G43iAKXrB3pqQg
# 80          5909 Sea Lion Pl Ste G Carlsbad, CA 92010  -STecUUsS69EMSE7PxwPwA
# 81                17029 Handlebar Rd Ramona, CA 92065  ZeiVSF1SMdVVSkiGE7qaSg
#
#               alias              title  rating  review_count price   latitude  \
# 0   winetastingroom  Wine Tasting Room     4.5           626    $$  33.032800
# 1   winetastingroom  Wine Tasting Room     5.0           100    $$  32.710751
# 2   winetastingroom  Wine Tasting Room     4.5           103    $$  32.754880
# 3   winetastingroom  Wine Tasting Room     4.5           138    $$  32.708732
# 4          wineries           Wineries     5.0            96    $$  33.068170
# ..              ...                ...     ...           ...   ...        ...
# 77         wineries           Wineries     4.0             1   NaN  33.037121
# 78         wineries           Wineries     5.0             1   NaN  32.534236
# 79  winetastingroom  Wine Tasting Room     4.5             7    $$  32.530430
# 80         wineries           Wineries     3.0             2   NaN  33.134743
# 81  winetastingroom  Wine Tasting Room     5.0             8     $  33.020150
#
#      longitude
# 0  -117.046460
# 1  -117.160918
# 2  -117.138280
# 3  -117.168195
# 4  -117.001600
# ..         ...
# 77 -117.238654
# 78 -117.034976
# 79 -117.036500
# 80 -117.248093
# 81 -116.928140
#
# [82 rows x 10 columns]

# %%
# list_test = df_test2.id
# list_test[list_test.str.startswith("-")]

# %%
# for item in df_test2['id']:
#     if item.startswith("-") == True:
#         item = None

# %%
def fix_csv_issue(df_var_name):
    for item in df_var_name['id']:
        if item.startswith("-") == True:
            df_var_name['id'].replace(to_replace=item, value = 0, inplace=True)
#     df_var_name = df_var_name['id'].dropna(inplace=True)
    
    return df_var_name

# %%
fix_csv_issue(df_test2)
# Out:
#                                              name  \
# 0                                 Bernardo Winery
# 1                      Callaway Vineyard & Winery
# 2                                Négociant Winery
# 3            San Pasqual Winery - Seaport Village
# 4              Domaine Artefact Vineyard & Winery
# ..                                            ...
# 77  Roll OutThe Barrell Charity Event by Meritage
# 78                               Licores Kentucky
# 79                                      Barrica 9
# 80                          RL Liquid Assets, Inc
# 81      Cactus Star Vineyard at Scaredy Cat Ranch
#
#                                              location                      id  \
# 0    13330 Paseo Del Verano Norte San Diego, CA 92128  DknnpiG1p4OoM1maFshzXA
# 1             517 4th Ave Ste 101 San Diego, CA 92101  Cn2_bpTngghYW1ej4zreZg
# 2              2419 El Cajon Blvd San Diego, CA 92104  Cc1sQWRWgGyMCjzX2mmMQQ
# 3                 805 W Harbor Dr San Diego, CA 92101  gMW1RvyLu90RSQAY9UrIHw
# 4        15404 Highland Valley Rd Escondido, CA 92025  WqVbxY77Ag96X90LultCUw
# ..                                                ...                     ...
# 77       162 S Rancho Santa Fe Rd Encinitas, CA 92024  wyLm9fIoamN-VALcu3nUVg
# 78  Calle Puerto y 3ra S/N Col. Centro 22000 Tijua...  B7gID-M2EsdpthrTcwTNYA
# 79  Av. Revolución 1265 Col. Zona Centro 22000 Tij...  HxTqmzT4G43iAKXrB3pqQg
# 80          5909 Sea Lion Pl Ste G Carlsbad, CA 92010  -STecUUsS69EMSE7PxwPwA
# 81                17029 Handlebar Rd Ramona, CA 92065  ZeiVSF1SMdVVSkiGE7qaSg
#
#               alias              title  rating  review_count price   latitude  \
# 0   winetastingroom  Wine Tasting Room     4.5           626    $$  33.032800
# 1   winetastingroom  Wine Tasting Room     5.0           100    $$  32.710751
# 2   winetastingroom  Wine Tasting Room     4.5           103    $$  32.754880
# 3   winetastingroom  Wine Tasting Room     4.5           138    $$  32.708732
# 4          wineries           Wineries     5.0            96    $$  33.068170
# ..              ...                ...     ...           ...   ...        ...
# 77         wineries           Wineries     4.0             1   NaN  33.037121
# 78         wineries           Wineries     5.0             1   NaN  32.534236
# 79  winetastingroom  Wine Tasting Room     4.5             7    $$  32.530430
# 80         wineries           Wineries     3.0             2   NaN  33.134743
# 81  winetastingroom  Wine Tasting Room     5.0             8     $  33.020150
#
#      longitude
# 0  -117.046460
# 1  -117.160918
# 2  -117.138280
# 3  -117.168195
# 4  -117.001600
# ..         ...
# 77 -117.238654
# 78 -117.034976
# 79 -117.036500
# 80 -117.248093
# 81 -116.928140
#
# [82 rows x 10 columns]

# %%
df_test2[~df_test2['id'].isna()]
# Out:
#                                              name  \
# 0                                 Bernardo Winery
# 1                      Callaway Vineyard & Winery
# 2                                Négociant Winery
# 3            San Pasqual Winery - Seaport Village
# 4              Domaine Artefact Vineyard & Winery
# ..                                            ...
# 77  Roll OutThe Barrell Charity Event by Meritage
# 78                               Licores Kentucky
# 79                                      Barrica 9
# 80                          RL Liquid Assets, Inc
# 81      Cactus Star Vineyard at Scaredy Cat Ranch
#
#                                              location                      id  \
# 0    13330 Paseo Del Verano Norte San Diego, CA 92128  DknnpiG1p4OoM1maFshzXA
# 1             517 4th Ave Ste 101 San Diego, CA 92101  Cn2_bpTngghYW1ej4zreZg
# 2              2419 El Cajon Blvd San Diego, CA 92104  Cc1sQWRWgGyMCjzX2mmMQQ
# 3                 805 W Harbor Dr San Diego, CA 92101  gMW1RvyLu90RSQAY9UrIHw
# 4        15404 Highland Valley Rd Escondido, CA 92025  WqVbxY77Ag96X90LultCUw
# ..                                                ...                     ...
# 77       162 S Rancho Santa Fe Rd Encinitas, CA 92024  wyLm9fIoamN-VALcu3nUVg
# 78  Calle Puerto y 3ra S/N Col. Centro 22000 Tijua...  B7gID-M2EsdpthrTcwTNYA
# 79  Av. Revolución 1265 Col. Zona Centro 22000 Tij...  HxTqmzT4G43iAKXrB3pqQg
# 80          5909 Sea Lion Pl Ste G Carlsbad, CA 92010  -STecUUsS69EMSE7PxwPwA
# 81                17029 Handlebar Rd Ramona, CA 92065  ZeiVSF1SMdVVSkiGE7qaSg
#
#               alias              title  rating  review_count price   latitude  \
# 0   winetastingroom  Wine Tasting Room     4.5           626    $$  33.032800
# 1   winetastingroom  Wine Tasting Room     5.0           100    $$  32.710751
# 2   winetastingroom  Wine Tasting Room     4.5           103    $$  32.754880
# 3   winetastingroom  Wine Tasting Room     4.5           138    $$  32.708732
# 4          wineries           Wineries     5.0            96    $$  33.068170
# ..              ...                ...     ...           ...   ...        ...
# 77         wineries           Wineries     4.0             1   NaN  33.037121
# 78         wineries           Wineries     5.0             1   NaN  32.534236
# 79  winetastingroom  Wine Tasting Room     4.5             7    $$  32.530430
# 80         wineries           Wineries     3.0             2   NaN  33.134743
# 81  winetastingroom  Wine Tasting Room     5.0             8     $  33.020150
#
#      longitude
# 0  -117.046460
# 1  -117.160918
# 2  -117.138280
# 3  -117.168195
# 4  -117.001600
# ..         ...
# 77 -117.238654
# 78 -117.034976
# 79 -117.036500
# 80 -117.248093
# 81 -116.928140
#
# [82 rows x 10 columns]

# %%
df_test2.dropna(axis=0, inplace=True)
df_test2
# Out:
#                                          name  \
# 0                             Bernardo Winery
# 1                  Callaway Vineyard & Winery
# 2                            Négociant Winery
# 3        San Pasqual Winery - Seaport Village
# 4          Domaine Artefact Vineyard & Winery
# 5                 Carruth Cellars Wine Garden
# 6                      Blue Door Urban Winery
# 58                                   Alpine, CA 91901  9c_BLUDYbND7lY30W_Rx1g
# 60                                 La Jolla, CA 92038  EzSpL_O4r00ZFg4BNi9qPw
# 61  Av. Cañón Johnson 2108 Col. Hidalgo 22130 Tiju...  W2not8gGBbjBMUeFmwdriA
# 62               13538 Poway Rd Ste B Poway, CA 92064  1YoSxgAOK625vP0lQpR5zw
# 63                 603 Main St Ste 9 Ramona, CA 92065  2H1dXyHAcdTxNrbqKbJ8Bg
# 65                      26502 Hwy 78 Ramona, CA 92065  YD8O_qG9BNlQm3OtzONDww
# 66           18750 - C Littlepage Rd Ramona, CA 92065  cfUvT3H6CGh_81U0Z-X7gw
# 68               17211 Highlander Dr Ramona, CA 92065  Tu52NWMO_dnv5v4iyuLykg
# 71              25260 Old Julian Hwy Ramona, CA 92065  C8W1fWjVOyA10rufYYfM6Q
# 72  Blvd. Salinas 10650 Col. Centro 22014 Tijuana,...  JVMnIFpnAxRNxHrJKqxWQg
# 74        298 Enterprise St Ste D Escondido, CA 92029  4nFSeNcQny91tOID2Jfv8Q
# 76                      17948 Hwy 67 Ramona, CA 92065  Nqy6NwQSTuAjsBpE7AoJYQ
# 79  Av. Revolución 1265 Col. Zona Centro 22000 Tij...  HxTqmzT4G43iAKXrB3pqQg
# 81                17029 Handlebar Rd Ramona, CA 92065  ZeiVSF1SMdVVSkiGE7qaSg
#
#               alias              title  rating  review_count price   latitude  \
# 0   winetastingroom  Wine Tasting Room     4.5           626    $$  33.032800
# 1   winetastingroom  Wine Tasting Room     5.0           100    $$  32.710751
# 2   winetastingroom  Wine Tasting Room     4.5           103    $$  32.754880
# 3   winetastingroom  Wine Tasting Room     4.5           138    $$  32.708732
# 4          wineries           Wineries     5.0            96    $$  33.068170
# 5          wineries           Wineries     4.5           196    $$  32.727480
# 6          wineries           Wineries     4.5            76    $$  32.814091
# 7          wineries           Wineries     4.0           547    $$  33.068118
# 8   winetastingroom  Wine Tasting Room     4.0           173    $$  32.726797
# 9          wineries           Wineries     4.5           308    $$  32.748217
# 10  winetastingroom  Wine Tasting Room     4.5            85    $$  32.814380
# 11  winetastingroom  Wine Tasting Room     4.5            55    $$  32.745389
# 13         wineries           Wineries     5.0           113    $$  32.986480
# 14         wineries           Wineries     4.5           111    $$  33.063290
# 15         wineries           Wineries     5.0            20    $$  32.771589
# 16  winetastingroom  Wine Tasting Room     4.0            43    $$  32.771626
# 17         wineries           Wineries     4.0            99    $$  33.023853
# 18         wineries           Wineries     5.0            38    $$  33.071770
# 19         wineries           Wineries     5.0             1    $$  32.715738
# 20         wineries           Wineries     4.5            26    $$  32.715435
# 22         wineries           Wineries     4.5            23    $$  33.021401
# 24         wineries           Wineries     5.0           155    $$  33.052156
# 26  winetastingroom  Wine Tasting Room     5.0           126    $$  33.070448
# 27  winetastingroom  Wine Tasting Room     4.5            12     $  32.896550
# 28  winetastingroom  Wine Tasting Room     4.5            99    $$  32.755568
# 31  winetastingroom  Wine Tasting Room     4.5            81    $$  32.765720
# 32         wineries           Wineries     5.0            39    $$  33.009689
# 33         wineries           Wineries     4.5            71    $$  33.024639
# 34  winetastingroom  Wine Tasting Room     4.5           103    $$  33.044200
# 36         wineries           Wineries     5.0            24    $$  32.639056
# 37  winetastingroom  Wine Tasting Room     4.5             3    $$  32.683768
# 39         wineries           Wineries     4.5            33    $$  33.123410
# 41         wineries           Wineries     4.5            45    $$  33.031777
# 44         wineries           Wineries     4.5           118    $$  33.093880
# 46         wineries           Wineries     5.0            19    $$  33.055500
# 47         wineries           Wineries     4.5            33    $$  33.063248
# 48  winetastingroom  Wine Tasting Room     4.0            14    $$  32.986339
# 49  winetastingroom  Wine Tasting Room     5.0             9    $$  33.049052
# 50         wineries           Wineries     5.0            26    $$  33.077897
# 51  winetastingroom  Wine Tasting Room     4.5            76    $$  33.102200
# 52         wineries           Wineries     4.5           114    $$  33.033070
# 53         wineries           Wineries     3.5            23    $$  33.008227
# 56         wineries           Wineries     4.0           247    $$  32.991630
# 58         wineries           Wineries     3.0             7    $$  32.835052
# 60         wineries           Wineries     4.0            14     $  32.837048
# 61  winetastingroom  Wine Tasting Room     4.0            35    $$  32.524224
# 62  winetastingroom  Wine Tasting Room     5.0            13    $$  32.956670
# 63         wineries           Wineries     4.5            54    $$  33.045533
# 65         wineries           Wineries     4.5            17    $$  33.066615
# 66         wineries           Wineries     4.5           141    $$  33.052468
# 68         wineries           Wineries     5.0            17    $$  33.028515
# 71         wineries           Wineries     5.0             1    $$  33.052360
# 72         wineries           Wineries     5.0             6   $$$  32.512608
# 74  winetastingroom  Wine Tasting Room     4.5            26    $$  33.121009
# 76         wineries           Wineries     3.5           144    $$  33.010505
# 79  winetastingroom  Wine Tasting Room     4.5             7    $$  32.530430
# 81  winetastingroom  Wine Tasting Room     5.0             8     $  33.020150
#
#      longitude
# 0  -117.046460
# 1  -117.160918
# 2  -117.138280
# 3  -117.168195
# 4  -117.001600
# 5  -117.170560
# 6  -117.218254
# 7  -116.991715
# 8  -117.169759
# 9  -117.149463
# 10 -117.269500
# 11 -117.248110
# 13 -117.072145
# 14 -117.004395
# 15 -117.021318
# 16 -117.021328
# 17 -117.085762
# 18 -117.008392
# 19 -117.161084
# 20 -116.847832
# 22 -116.936933
# 24 -116.783193
# 26 -117.009454
# 27 -117.137430
# 28 -117.196903
# 31 -117.017870
# 32 -116.858495
# 33 -116.932663
# 34 -116.828583
# 36 -116.769926
# 37 -117.092312
# 39 -117.132970
# 41 -116.821265
# 44 -117.030080
# 46 -116.777470
# 47 -116.843803
# 48 -116.916558
# 49 -116.808999
# 50 -116.961576
# 51 -117.086850
# 52 -116.825775
# 53 -116.924342
# 56 -117.270140
# 58 -116.766411
# 60 -117.255386
# 61 -117.037935
# 62 -117.037957
# 63 -116.862483
# 65 -116.757815
# 66 -116.750704
# 68 -116.953087
# 71 -116.782590
# 72 -117.002464
# 74 -117.115748
# 76 -116.919508
# 79 -117.036500
# 81 -116.928140

# %% [markdown]
# ## Saving Data
